# %%
import pandas as pd
import re 
import numpy as np

df=pd.read_csv("../my-code/dffinal.csv")

# %%
display(df)
# Out:
#          Period    Country             Area         Type Fatal (Y/N)  \
# 0     1997-2016  AUSTRALIA         Victoria   Unprovoked           N
# 1     1937-1956  AUSTRALIA  South Australia     Provoked     Unknown
# 2     1937-1956  AUSTRALIA  New South Wales   Unprovoked           Y
# 3     1997-2016  AUSTRALIA  New South Wales   Unprovoked           N
# 4     1997-2016  AUSTRALIA  New South Wales  Unspecified           Y
# ...         ...        ...              ...          ...         ...
# 3743  1997-2016        USA          Florida   Unprovoked           N
# 3744  1997-2016        USA         Virginia  Unspecified           N
# 3745  1997-2016        USA          Florida     Provoked           N
# 3746  1997-2016        USA          Florida   Unprovoked           N
# 3747  1916-1936        USA  North Carolina    Unprovoked           N
#
#              Time
# 0         Morning
# 1     Unspecified
# 2       Afternoon
# 3         Morning
# 4     Unspecified
# ...           ...
# ...
