# %%
import pandas as pd
import re 

df=pd.read_csv("../attacks.csv")
display(df.head())
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %%
file_list = [f for f in df]
print(file_list)
# Out:
# ['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23']

# %%
#busco comprobar cuantos valores en cada columna son nulos, sabiendo que el total de valores contenidos en cada columna
#nulos o no, son 25723
print(len(df.index)) 


null_cols= df.isnull().sum()
print(null_cols)
# Out:
# 5992
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
#según lo realizado anteriormente, observo en las columnas Unnamed 22 y Unnamed 23 que solo hay 1 y 2 valores
#para comprobar cuales son estos valores y si merecería la pena quedarnos con ellos imprimo aquellos que contienen 
#valores no nulos, comprobando que en efecto, no son relevantes (stopped here, Teramo, change filename)

df= df.rename(columns={"Unnamed: 22": "Unnamed"})
df= df.rename(columns={"Unnamed: 23": "Unnamed1"})

Unnamed_not_null = df[df.Unnamed.notnull()]
display(Unnamed_not_null.head())

Unnamed_not_null = df[df.Unnamed1.notnull()]
display(Unnamed_not_null.head())
# Out:
#      Case Number       Date  Year        Type Country        Area  \
# 1247  2006.06.18  18-Jun-06  2006  Unprovoked  BRAZIL  Pernambuco
#
#                             Location       Activity                     Name  \
# 1247  Punta Del Chifre Beach, Olinda  Body boarding  Humberto Pessoa Batista
#
#      Sex   ... Species  Investigator or Source                     pdf  \
# 1247    M  ...      NaN     globalsurfnews.com  2006.06.18-Batista.pdf
#
#                                            href formula  \
# 1247  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 1247  http://sharkattackfile.net/spreadsheets/pdf_di...    2006.06.18
#
#      Case Number.2 original order       Unnamed Unnamed1
# 1247    2006.06.18           4746  stopped here      NaN
#
# [1 rows x 24 columns]
#      Case Number         Date  Year      Type    Country             Area  \
# ...

# %%
#eliminamos por tanto las columnas valoradas anteriormente
df= df.drop(["Unnamed","Unnamed1"], axis=1)
df
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
years = df['Year'].value_counts()
years[years>25]
# Out:
# 2015    139
# 2011    128
# 2014    125
# 2013    122
# 2008    121
#        ...
# 1941     27
# 1977     26
# 1930     26
# 1928     26
# 1946     26
# Name: Year, Length: 82, dtype: int64

# %%
##The first recorded human fatality by shark was noted as having occurred on July 12, 1771
#but the real shit started in 1916
#https://es.wikipedia.org/wiki/Ola_de_ataques_de_tibur%C3%B3n_de_Nueva_Jersey_de_1916


df = df.drop(df[df['Year']<1916].index)
df
# Out:
#        Case Number                  Date  Year        Type    Country  \
# 0     2016.09.18.c             18-Sep-16  2016  Unprovoked        USA
# 1     2016.09.18.b             18-Sep-16  2016  Unprovoked        USA
# 2     2016.09.18.a             18-Sep-16  2016  Unprovoked        USA
# 3       2016.09.17             17-Sep-16  2016  Unprovoked  AUSTRALIA
# 4       2016.09.15             16-Sep-16  2016  Unprovoked  AUSTRALIA
# ...            ...                   ...   ...         ...        ...
# 5836  1785.09.26.R  Reported 26-Sep-1785  1785  Unprovoked    ENGLAND
# 5837    1779.00.00                  1779  1779  Unprovoked        USA
# 5838  1776.00.00.R         Reported 1776  1776  Unprovoked     GUINEA
# 5839  1776.00.00.b                  1776  1776        Boat  GREENLAND
# 5840  1771.07.12.R  Reported 12-Jul-1771  1771  Unprovoked        USA
#
#           Area                          Location Activity  \
# 0      Florida  New Smyrna Beach, Volusia County  Surfing
# ...
