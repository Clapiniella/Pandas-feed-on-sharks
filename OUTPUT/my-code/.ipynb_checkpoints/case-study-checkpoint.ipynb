# %% [markdown]
# # PROJECT

# %% [markdown]
# ###  PASO PRELIMINAR
#
# En primer lugar, importamos la base de datos con la que vamos a trabajar, el Input.
# Además cargamos las librerias que nos serán necesarias, además de estudiar las características principales del DF.

# %%
import pandas as pd
import re 
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12, 'figure.figsize': (5, 5)})

df=pd.read_csv("../attacks.csv")

# %%
file_list = [f for f in df]
print(file_list)
# Out:
# ['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23']

# %%
df.rename(columns={"Sex ":"Sex"}, inplace=True)
df.rename(columns={"Species ":"Species"}, inplace=True)

# %% [markdown]
# Esta primera observación nos será suficiente para desechar alguna de las columnas de la DF original.

# %%
df= df.drop(["Name","Sex","Injury","Species","Investigator or Source","pdf","href formula","href","original order"], axis=1)

# %%
print(df.shape)
print(df.dtypes)
null_cols= df.isnull().sum()
# Out:
# (5992, 15)
# Case Number      object
# Date             object
# Year              int64
# Type             object
# Country          object
# Area             object
# Location         object
# Activity         object
# Age              object
# Fatal (Y/N)      object
# Time             object
# Case Number.1    object
# Case Number.2    object
# Unnamed: 22      object
# Unnamed: 23      object
# dtype: object

# %%
df["Year"] = df["Year"].astype(str)

# %% [markdown]
# # PASO 1. Data Cleaning

# %% [markdown]
# Durante este paso, buscaremos a través de la metodología aprendida, realizar un Data Cleaning que nos permita acceder a un DF con datos útiles.
#
# Realizando este proceso, columna por columna.

# %% [markdown]
# # Column Unnamed: 22 & 23

# %% [markdown]
# En esta Columna, buscamos observar aquellos valores que no son nulos. Según lo realizado anteriormente, observo en las columnas Unnamed 22 y Unnamed 23 que solo hay 1 y 2 valores, para comprobar cuales son estos valores y si merecería la pena quedarnos con ellos imprimo aquellos que contienen valores no nulos, comprobando que en efecto, no son relevantes (stopped here, Teramo, change filename). Eliminamos por tanto las columnas valoradas anteriormente.

# %%
df= df.rename(columns={"Unnamed: 22": "Unnamed"})
df= df.rename(columns={"Unnamed: 23": "Unnamed1"})

Unnamed_not_null = df[df.Unnamed.notnull()]
display(Unnamed_not_null.head())

Unnamed_not_null = df[df.Unnamed1.notnull()]
display(Unnamed_not_null.head())
# Out:
#      Case Number       Date  Year        Type Country        Area  \
# 1247  2006.06.18  18-Jun-06  2006  Unprovoked  BRAZIL  Pernambuco
#
#                             Location       Activity Age Fatal (Y/N)   Time  \
# 1247  Punta Del Chifre Beach, Olinda  Body boarding  27           Y  09h00
#
#      Case Number.1 Case Number.2       Unnamed Unnamed1
# 1247    2006.06.18    2006.06.18  stopped here      NaN
#      Case Number         Date  Year      Type    Country             Area  \
# 4182  1952.07.13    13-Jul-52  1952  Provoked        USA       California
# 5585  1879.03.10  10-Mar-1879  1879   Invalid  AUSTRALIA  New South Wales
#
#                          Location  \
# 4182  San Diego, San Diego County
# 5585                 Near Sydney
#
#                                            Activity  Age Fatal (Y/N) Time  \
# 4182                                        Fishing   34           N  NaN
# 5585  The steamship Bonnie Dundee lost in collision  NaN           Y  NaN
#
#      Case Number.1 Case Number.2 Unnamed         Unnamed1
# 4182    1952.07.13    1952.07.13     NaN           Teramo
# 5585    1879.03.10    1879.03.10     NaN  change filename

# %%
df= df.drop(["Unnamed","Unnamed1"], axis=1)

# %% [markdown]
# # Column Case Number

# %% [markdown]
# Para la columna Case Number, encontramos tres columnas similares. Es por esto que me centraré en realizar un análisis de las diferencias encontradas. Corrigiendo alguna de estas diferencias y quedandonos con aquella columna que encontramos "más limpia".

# %%
print(df['Case Number'].equals(df['Case Number.1']))
print(df['Case Number.1'].equals(df['Case Number.2']))
print(df['Case Number'].equals(df['Case Number.2']))
case_number=df[["Case Number","Case Number.1","Case Number.2"]]
#nada_igual = case_number[case_number["Case Number"]!=case_number["Case Number.1"]]
nadita_igual = case_number[case_number["Case Number"]!=case_number["Case Number.2"]]
#nad_igual = case_number[case_number["Case Number.1"]!=case_number["Case Number.2"]]
display(nadita_igual)
# Out:
# False
# False
# False
#        Case Number Case Number.1 Case Number.2
# 169     2015.07-10    2015.07.10    2015.07.10
# 4719  1934.01.08.R  1934.02.08.R  1934.02.08.R

# %%
df = df.drop(columns=["Case Number"])

# %%
case_number2=df[["Case Number.1","Case Number.2"]]
nad_igual = case_number2[case_number2["Case Number.1"]!=case_number2["Case Number.2"]]
display(nad_igual)
# Out:
#      Case Number.1 Case Number.2
# 4       2016.09.16    2016.09.15
# 33    2016.07.14.R  2016.07.14.4
# 97    2015.01.24.b  2016.01.24.b
# 116     2015.11.07    2015.12.23
# 121     2015.10.28  2015.10.28.a
# 3296    1967/07.05    1967.07.05
# 3569  1962.08.30.b  1962,08.30.b
# 3654  1961.09,06.R  1961.09.02.R
# 4177    1952.08.04    1952.08.05
# 5043  1919.00.00.R  1900.00.00.R
# 5150  1911.07.31.T  1911.07.31.R

# %%
df = df.drop(columns=["Case Number.1"])

# %%
df.rename(columns={"Case Number.2":"Case Number"}, inplace=True)

# %%
df['Case Number'] = df['Case Number'].str.replace(",",".", regex=False)

# %%
df=df[["Case Number","Date","Year","Type", "Country", "Area", "Location", "Activity", "Age", "Fatal (Y/N)", "Time"]]

# %% [markdown]
# # Column Country

# %% [markdown]
# Teniendo en cuenta que Country va a ser un valor relevante en mi estudio, observo cuales de esos valores nulos
# puedo recuperar de otras columnas, pero a este respecto no encuentro información, no obstante, decido no tener en cuenta dichas filas, por falta de información y porque solo representa el 43/5992) de la población de datos, y por tanto no es representativa, o no debería afectar en gran medida a los resultados del análisis.

# %%
filtered = df[(df['Country'].isnull())]

print(filtered.shape)
# Out:
# (0, 7)

# %% [markdown]
# Agrupamos England y Scotland como United Kingdom.

# %%
df['Country'] = df['Country'].str.replace('ENGLAND', 'UNITED KINGDOM')
df['Country'] = df['Country'].str.replace('SCOTLAND', 'UNITED KINGDOM')

filtered = df[(df['Country']=="UNITED KINGDOM")]
print(filtered.shape)
filtered.head()
# Out:
# (37, 11)
#       Case Number                  Date  Year        Type         Country  \
# 526    2012.08.31             31-Aug-12  2012    Provoked  UNITED KINGDOM
# 625  2011.10.28.R  Reported 28-Oct-2011  2011  Unprovoked  UNITED KINGDOM
# 688  2011.06.14.R  Reported 14-Jun-2011  2011        Boat  UNITED KINGDOM
# 860    2009.10.17             17-Oct-09  2009    Provoked  UNITED KINGDOM
# 863    2009.10.02             02-Oct-09  2009    Provoked  UNITED KINGDOM
#
#                Area                 Location       Activity  Age Fatal (Y/N)  \
# 526  Inner Hebrides    Off the Isle of Islay  Shark fishing   53           N
# 625           Moray                 Spey Bay        Surfing   26           N
# 688        Cornwall                 St. Ives        Fishing  NaN           N
# 860            Fife  Deep Sea World Aquarium         Diving   23           N
# 863           Devon            Mewstone Rock        Fishing   39           N
#
#       Time
# 526    NaN
# 625    NaN
# 688    NaN
# 860  14h45
# 863  12h50

# %% [markdown]
# El cliente nos ha pedido analizar las características de los ataques por zona en cada país en el que tiene actividad, por lo que solo tendremos en cuenta dichos países.

# %%
COUNTRIES= ["UNITED KINGDOM","MALTA","NEW ZEALAND","FRANCE","CHINA","JAPAN","ITALY","SINGAPORE","AUSTRALIA","USA","CANADA","IRELAND","SOUTH AFRICA", "GERMANY"]
df= df.loc[df["Country"].isin(COUNTRIES)]

# %%
counts = df['Country'].value_counts()
display(counts)
# Out:
# USA               2116
# AUSTRALIA         1279
# SOUTH AFRICA       565
# NEW ZEALAND        125
# ITALY               71
# UNITED KINGDOM      37
# JAPAN               32
# FRANCE              13
# CANADA              10
# CHINA                6
# SINGAPORE            6
# MALTA                5
# IRELAND              1
# Name: Country, dtype: int64

# %% [markdown]
# # Columna Fatal

# %% [markdown]
# En esta columna, la limpieza consistirá en configurar el mismo formato para los diferentes valores, además de realizar un Apply para una función que buscará relocalizar las variables, de modo que solo exitan 3 grupos.

# %%
df["Fatal (Y/N)"].value_counts()
# Out:
# N          3381
# Y           805
# UNKNOWN      63
#  N            6
# #VALUE!       1
# n             1
# N             1
# Name: Fatal (Y/N), dtype: int64

# %%
df["Fatal (Y/N)"] = df["Fatal (Y/N)"].str.strip()

# %%
def homog_fatal(f): 
    if f not in ["N", "Y"]: 
        return 'Unknown'
    else: 
        return f
    
df["Fatal (Y/N)"] = df["Fatal (Y/N)"].apply(homog_fatal)
df["Fatal (Y/N)"].value_counts()
# Out:
# N          3388
# Y           805
# Unknown      73
# Name: Fatal (Y/N), dtype: int64

# %% [markdown]
# # Columna Type

# %%
df["Type"] = df["Type"].str.strip() 
df["Type"].value_counts()
# Out:
# Unprovoked      3100
# Provoked         444
# Invalid          392
# Boat             173
# Boating           90
# Sea Disaster      67
# Name: Type, dtype: int64

# %%
df["Type"] = df["Type"].str.replace('Invalid', 'Unspecified')
df["Type"] = df["Type"].str.replace('Sea Disaster', 'Unprovoked')
df.loc[df['Type'].str.startswith('Boat'), "Type"] = 'Provoked'

# %%
df["Type"].value_counts()
# Out:
# Unprovoked     3167
# Provoked        707
# Unspecified     392
# Name: Type, dtype: int64

# %% [markdown]
# # Columna Time

# %%
df["Time"] = df["Time"].str.replace('>', '')
df["Time"] = df["Time"].str.replace('<', '')
df["Time"] = df["Time"].str.replace('h', '')
df["Time"] = df["Time"].str.replace('Before', '')
df["Time"] = df["Time"].str.replace('Early', '')
df["Time"] = df["Time"].str.replace('Earlyafter', '')
df["Time"] = df["Time"].str.replace('A.M.', 'Morning')
df["Time"] = df["Time"].str.replace('AM', 'Morning')
df["Time"] = df["Time"].str.replace('PM', 'Morning')
df["Time"] = df["Time"].str.replace('Sometimebetween0600&08oo', 'Morning')
df["Time"] = df["Time"].str.replace('2rsbeforesunset', 'Morning')
df["Time"] = df["Time"].str.replace('morning', 'Morning')
df["Time"] = df["Time"].str.replace('Nigt', 'Evening')
df["Time"] = df["Time"].str.replace('P.M.', 'Evening')
df["Time"] = df["Time"].str.replace('Dusk', 'Evening')
df["Time"] = df["Time"].str.replace(' ', '')
df["Time"] = df["Time"].str.replace('Late', '')
df["Time"] = df["Time"].str.replace('Mid', '')
df["Time"] = df["Time"].str.replace('Mid-', '')
df["Time"] = df["Time"].str.replace('j', '')
df["Time"] = df["Time"].str.replace('After', '')
df["Time"] = df["Time"].str.replace('Late afternon', 'Afternoon')
df["Time"] = df["Time"].str.replace('Late afternoon', 'Afternoon')
df["Time"] = df["Time"].str.replace('Early afternoon', 'Afternoon')
df["Time"] = df["Time"].str.replace('noon', 'Afternoon')
df["Time"] = df["Time"].str.replace('Midday.', 'Afternoon')
df["Time"] = df["Time"].str.replace('Midday', 'Afternoon')
df["Time"] = df["Time"].str.replace('Possiblysameincidentas2000.08.21', 'Unspecified')
df["Time"] = df["Time"].str.replace('FATAL  (Wire netting installed at local beaces after tis incident.)', 'Unspecified')
df["Time"] = df["Time"].str.replace('FATAL(Wire netting installed at local beaces after tis incident.)', 'Unspecified')
df["Time"] = df["Time"].str.replace('Sortlybefore1300', 'Afternoon')
df["Time"] = df["Time"].str.replace('1101 -time of sip sinking', 'Afternoon')
df["Time"] = df["Time"].str.replace('Between 1100 & 1200', 'Morning')
df["Time"] = df["Time"].str.replace('"sortly before dusk"', 'Evening')
df["Time"] = df["Time"].str.replace('2 rs before sunset', 'Unspecified')
df["Time"] = df["Time"].str.replace('--', 'Unspecified')

# %%
df["Time"] = df["Time"].str.replace('Lateafter', '')
df["Time"] = df["Time"].str.replace('after', '')

# %%
df["Time"]= df["Time"].fillna("Unspecified")

# %%
df.loc[df['Time'].str.startswith('01'), 'Time'] = 'Evening'
df.loc[df['Time'].str.startswith('02'), 'Time'] = 'Evening'
df.loc[df['Time'].str.startswith('03'), 'Time'] = 'Evening'
df.loc[df['Time'].str.startswith('04'), 'Time'] = 'Evening'
df.loc[df['Time'].str.startswith('05'), 'Time'] = 'Evening'
df.loc[df['Time'].str.startswith('06'), 'Time'] = 'Morning'
df.loc[df['Time'].str.startswith('07'), 'Time'] = 'Morning'
df.loc[df['Time'].str.startswith('08'), 'Time'] = 'Morning'
df.loc[df['Time'].str.startswith('09'), 'Time'] = 'Morning'
df.loc[df['Time'].str.startswith('10'), 'Time'] = 'Morning'
df.loc[df['Time'].str.startswith('11'), 'Time'] = 'Morning'
df.loc[df['Time'].str.startswith('12'), 'Time'] = 'Afternoon'
df.loc[df['Time'].str.startswith('13'), 'Time'] = 'Afternoon'
df.loc[df['Time'].str.startswith('14'), 'Time'] = 'Afternoon'
df.loc[df['Time'].str.startswith('15'), 'Time'] = 'Afternoon'
df.loc[df['Time'].str.startswith('16'), 'Time'] = 'Afternoon'
df.loc[df['Time'].str.startswith('17'), 'Time'] = 'Afternoon'
df.loc[df['Time'].str.startswith('18'), 'Time'] = 'Evening'
df.loc[df['Time'].str.startswith('19'), 'Time'] = 'Evening'
df.loc[df['Time'].str.startswith('20'), 'Time'] = 'Evening'
df.loc[df['Time'].str.startswith('21'), 'Time'] = 'Evening'
df.loc[df['Time'].str.startswith('22'), 'Time'] = 'Evening'
df.loc[df['Time'].str.startswith('23'), 'Time'] = 'Evening'
df.loc[df['Time'].str.startswith('00'), 'Time'] = 'Evening'

# %%
df["Time"].value_counts()
# Out:
# Unspecified                 1992
# Afternoon                   1234
# Morning                      702
# Evening                      290
# day                            5
# Sunset                         4
# nigt                           4
#                                3
# non                            2
# "Evening"                      2
# JustbeforeAfternoon            2
# Dawn                           2
# Between0500and0800             1
# daybreak                       1
# Priorto1037                    1
# Noon                           1
# 830                            1
# "evening"                      1
# Dark                           1
# Sortlymidnigt                  1
# Daybreak                       1
# "dark"                         1
# Eveningfall                    1
# -Morning                       1
# Lunctime                       1
# 8:04Morning                    1
# 2oursOpperman                  1
# Justbeforesundown              1
# dusk                           1
# X                              1
# "lunc"                         1
# Daytime                        1
# "Justbefore1100"               1
# Just1200                       1
#                                1
# Sometimebetween0600&08oo       1
# Name: Time, dtype: int64

# %%
def homog_fatal(h): 
    if h not in ['Afternoon', 'Morning', 'Evening']: 
        return 'Unspecified'
    else: 
        return h
    
df["Time"] = df["Time"].apply(homog_fatal)
df["Time"].value_counts()
# Out:
# Unspecified    2040
# Afternoon      1234
# Morning         702
# Evening         290
# Name: Time, dtype: int64

# %% [markdown]
# # Column Area

# %%
df["Area"].value_counts()
# Out:
# Florida              990
# New South Wales      468
# Queensland           300
# Hawaii               282
# California           276
#                     ...
# Mercury Islands        1
# Kagawa Prefecture      1
# Cook islans            1
# Aichi Prefecture       1
# New Brunswick          1
# Name: Area, Length: 183, dtype: int64

# %%
df["Area"]= df["Area"].fillna("Unspecified")

# %%
count = df['Area'].value_counts()
count[count > 20]
df=df[df['Area'].isin(count[count >20].index)]
df["Area"].value_counts()
# Out:
# Florida                  990
# New South Wales          468
# Queensland               300
# Hawaii                   282
# California               276
# KwaZulu-Natal            210
# Western Cape Province    188
# Western Australia        172
# Eastern Cape Province    156
# South Carolina           144
# South Australia          103
# North Carolina           100
# Victoria                  81
# Texas                     71
# Torres Strait             70
# North Island              65
# New Jersey                49
# Unspecified               46
# Tasmania                  41
# South Island              39
# Oregon                    28
# New York                  27
# Northern Territory        23
# Name: Area, dtype: int64

# %% [markdown]
# # Column Year

# %%
df["Year"].value_counts()
# Out:
# 2015    111
# 2014     96
# 2012     95
# 2008     90
# 2013     88
#        ...
# 1841      1
# 1803      1
# 1807      1
# 1869      1
# 1859      1
# Name: Year, Length: 188, dtype: int64

# %%
filtered = df[(df['Year']=="0")]

# %%
df["Date"] = df["Date"].str.replace("Before ", '')
df["Date"] = df["Date"].str.replace("Beforer ", '')
df["Date"] = df["Date"].str.replace("No date,Before ", '')
df["Date"] = df["Date"].str.replace("No date, ", '')
df["Date"] = df["Date"].str.replace("?", '')

# %%
filtered = df[(df['Year']=="0")]

# %%
df['Year'] = np.where(df['Year'] == "0", df['Date'], df["Year"])

# %%
#Ya le he dado utilidad a Date y por tanto, procedo a eliminarla

df = df.drop(columns=["Date"])

# %%
display(df)
# Out:
#        Case Number       Year        Type    Country               Area  \
# 0     2016.09.18.c       2016  Unprovoked        USA            Florida
# 1     2016.09.18.b       2016  Unprovoked        USA            Florida
# 2     2016.09.18.a       2016  Unprovoked        USA            Florida
# 3       2016.09.17       2016  Unprovoked  AUSTRALIA           Victoria
# 4       2016.09.15       2016  Unprovoked  AUSTRALIA           Victoria
# ...            ...        ...         ...        ...                ...
# 5985       ND.0007       1906  Unprovoked  AUSTRALIA        Unspecified
# 5986       ND.0006       1906  Unprovoked  AUSTRALIA    New South Wales
# 5987       ND.0005       1903  Unprovoked  AUSTRALIA  Western Australia
# 5988       ND.0004       1903  Unprovoked  AUSTRALIA  Western Australia
# 5989       ND.0003  1900-1905  Unprovoked        USA     North Carolina
#
#                               Location      Activity  Age Fatal (Y/N)  \
# 0     New Smyrna Beach, Volusia County       Surfing   16           N
# 1     New Smyrna Beach, Volusia County       Surfing   36           N
# 2     New Smyrna Beach, Volusia County       Surfing   43           N
# 3                     Thirteenth Beach       Surfing  NaN           N
# 4                          Bells Beach       Surfing  NaN           N
# ...                                ...           ...  ...         ...
# 5985                               NaN       Fishing  NaN           Y
# 5986                                        Swimming  NaN           Y
# 5987                       Roebuck Bay        Diving  NaN           Y
# 5988                               NaN  Pearl diving  NaN           Y
# 5989                    Ocracoke Inlet      Swimming  NaN           Y
#
#              Time
# 0       Afternoon
# 1         Morning
# 2         Morning
# 3     Unspecified
# 4     Unspecified
# ...           ...
# 5985  Unspecified
# 5986  Unspecified
# 5987  Unspecified
# 5988  Unspecified
# 5989  Unspecified
#
# [3929 rows x 10 columns]

# %%
df["Year"] = df["Year"].str.replace("Ca. 725 B.C.", '725')
df["Year"] = df["Year"].str.replace("1880-1899", '1899')
df["Year"] = df["Year"].str.replace("08-Jun-1912", '1912')
df["Year"] = df["Year"].str.replace("s", '')
df["Year"] = df["Year"].str.replace("No date (3 days after preceding incident) & prior to 19-Jul-1913", 'No date')
df["Year"] = df["Year"].str.replace("A few years before 1938", '1938')
df["Year"] = df["Year"].str.replace("A few years before 1938", '1938')
df["Year"] = df["Year"].str.replace("After August 1926 and before 1936", '1936')
df["Year"] = df["Year"].str.replace("Circa 1862", '1862')
df["Year"] = df["Year"].str.replace("17-Jul-1916", '1916')
df["Year"] = df["Year"].str.replace("19-Jun-1959", '1959')
df["Year"] = df["Year"].str.replace("         19-Jul-1913", '1913')
df["Year"] = df["Year"].str.replace("3-Jan-1967", '1967')
df["Year"] = df["Year"].str.replace("'Nodate(3dayafterprecedingincident)&priorto19-Jul-1913'", '1913')
df["Year"] = df["Year"].str.replace(" ", '')
df["Year"] = df["Year"].str.replace("Nodate", '0')
df["Year"] = df["Year"].str.replace('"thewar"', '0')
df["Year"] = df["Year"].str.replace("Afewyearbefore1938", '0')

# %%
df["Year"] = df["Year"].str.replace("1920-1923", '1923')
df["Year"] = df["Year"].str.replace("1900-1905", '1905')
df["Year"] = df["Year"].str.replace("AfterAugut1926andbefore1936", '1936')

# %%
df=df[df.Year != "0(3dayafterprecedingincident)&priorto19-Jul-1913"]

# %%
df["Year"] = df["Year"].astype(int)

# %%
##The first recorded human fatality by shark was noted as having occurred on July 12, 1771
#but the real shit started in 1916
#https://es.wikipedia.org/wiki/Ola_de_ataques_de_tibur%C3%B3n_de_Nueva_Jersey_de_1916
df = df.drop(df[df['Year']<1916].index)

# %%
cutoffs = [1915,1936,1956,1976,1996,2016]
year_labels = ['1916-1936', '1937-1956', '1957-1976','1977-1996','1997-2016']
df['Period'] = pd.cut(df['Year'], cutoffs, labels = year_labels)
df['Period'].value_counts()
# Out:
# 1997-2016    1522
# 1977-1996     665
# 1957-1976     641
# 1916-1936     331
# 1937-1956     327
# Name: Period, dtype: int64

# %% [markdown]
# # PASO 2. Preparación para el análisis

# %%
#por falta de tiempo no puedo limpiar las columnas Location, Activity y Age <Pendiente>
#elimino Year ya que ya he obtenido los periodos
#elimino Case Number porque no lo considero relevante para el análisis
df= df.drop(["Location","Activity","Age","Year","Case Number"], axis=1)

# %%
df=df[["Period","Country", "Area","Type","Fatal (Y/N)", "Time"]]
display(df)
# Out:
#          Period       Country             Area        Type Fatal (Y/N)  \
# 0     1997-2016           USA          Florida  Unprovoked           N
# 1     1997-2016           USA          Florida  Unprovoked           N
# 2     1997-2016           USA          Florida  Unprovoked           N
# 3     1997-2016     AUSTRALIA         Victoria  Unprovoked           N
# 4     1997-2016     AUSTRALIA         Victoria  Unprovoked           N
# ...         ...           ...              ...         ...         ...
# 5967  1916-1936     AUSTRALIA  New South Wales  Unprovoked     Unknown
# 5972  1916-1936     AUSTRALIA       Queensland  Unprovoked           Y
# 5973  1916-1936           USA          Florida  Unprovoked           N
# 5975  1916-1936  SOUTH AFRICA    KwaZulu-Natal  Unprovoked           Y
# 5976  1916-1936  SOUTH AFRICA    KwaZulu-Natal  Unprovoked           Y
#
#              Time
# 0       Afternoon
# 1         Morning
# 2         Morning
# 3     Unspecified
# 4     Unspecified
# ...           ...
# 5967  Unspecified
# 5972  Unspecified
# 5973  Unspecified
# 5975  Unspecified
# 5976  Unspecified
#
# [3486 rows x 6 columns]

# %%
dfinal = df.sort_values('Country',ascending=True)

display(dfinal)
# Out:
#          Period    Country               Area        Type Fatal (Y/N)  \
# 3817  1957-1976  AUSTRALIA           Victoria  Unprovoked           N
# 1149  1997-2016  AUSTRALIA    New South Wales  Unprovoked           N
# 3639  1957-1976  AUSTRALIA  Western Australia    Provoked           N
# 3640  1957-1976  AUSTRALIA    South Australia    Provoked           N
# 3642  1957-1976  AUSTRALIA         Queensland  Unprovoked           Y
# ...         ...        ...                ...         ...         ...
# 1595  1997-2016        USA            Florida  Unprovoked           N
# 1596  1997-2016        USA            Florida  Unprovoked           N
# 1597  1997-2016        USA            Florida  Unprovoked           N
# 1585  1997-2016        USA         California  Unprovoked           N
# 0     1997-2016        USA            Florida  Unprovoked           N
#
#              Time
# 3817    Afternoon
# 1149  Unspecified
# 3639      Morning
# 3640  Unspecified
# 3642      Morning
# ...           ...
# 1595    Afternoon
# 1596    Afternoon
# 1597    Afternoon
# 1585      Morning
# 0       Afternoon
#
# [3486 rows x 6 columns]

# %%
export_csv = dfinal.to_csv ('../my-code/dfinal.csv', index=None, header=True)

# %% [markdown]
# # PASO 3. Análisis y conclusiones

# %%
new_df = dfinal.copy()

# %%
df4= df[["Country","Area"]]
df4.drop_duplicates()
# Out:
#              Country                   Area
# 0                USA                Florida
# 3          AUSTRALIA               Victoria
# 5          AUSTRALIA      Western Australia
# 7                USA                 Hawaii
# 9                USA         South Carolina
# 12               USA             California
# 24         AUSTRALIA        New South Wales
# 26         AUSTRALIA               Tasmania
# 28         AUSTRALIA             Queensland
# 41               USA         North Carolina
# 43      SOUTH AFRICA  Western Cape Province
# 48               USA                  Texas
# 65       NEW ZEALAND           North Island
# 85         AUSTRALIA        South Australia
# 94      SOUTH AFRICA          KwaZulu-Natal
# 111     SOUTH AFRICA  Eastern Cape Province
# 247            JAPAN            Unspecified
# 343     SOUTH AFRICA            Unspecified
# 362      NEW ZEALAND           South Island
# 366      NEW ZEALAND            Unspecified
# 377              USA                 Oregon
# 380              USA             New Jersey
# 779            MALTA            Unspecified
# 792              USA               New York
# 829        AUSTRALIA          Torres Strait
# 973        AUSTRALIA     Northern Territory
# 1219           ITALY            Unspecified
# 1345       AUSTRALIA            Unspecified
# 2799  UNITED KINGDOM            Unspecified
# 3270             USA            Unspecified
# 3317       SINGAPORE            Unspecified
# 4284           CHINA            Unspecified

# %%
df3= pd.crosstab(new_df['Area'],new_df['Type']).apply(lambda r: (r/r.sum())*100, axis=1)
df5= pd.crosstab(new_df['Area'],new_df['Fatal (Y/N)']).apply(lambda r: (r/r.sum())*100, axis=1)
df7= pd.crosstab(new_df['Area'],new_df['Time']).apply(lambda r: (r/r.sum())*100, axis=1)

# %%
df6 = pd.merge(df3, df4, on='Area')
df8 = pd.merge(df5, df4, on='Area')
df9 = pd.merge(df7, df4, on='Area')
df6 = df6.drop_duplicates()
df8 = df8.drop_duplicates()
df9 = df9.drop_duplicates()

# %%
display(df6)
display(df8)
display(df9)
# Out:
#                        Area   Provoked  Unprovoked  Unspecified  \
# 0                California  20.370370   68.888889    10.740741
# 270   Eastern Cape Province  10.135135   83.108108     6.756757
# 418                 Florida   9.558824   84.243697     6.197479
# 1370                 Hawaii   5.645161   83.064516    11.290323
# 1618          KwaZulu-Natal  13.089005   68.062827    18.848168
# 1809             New Jersey  37.142857   54.285714     8.571429
# 1844        New South Wales  21.727749   69.109948     9.162304
# 2226               New York  38.461538   23.076923    38.461538
# 2239         North Carolina   4.545455   84.090909    11.363636
# 2327           North Island  46.153846   43.589744    10.256410
# 2366     Northern Territory  38.095238   52.380952     9.523810
# 2387                 Oregon   0.000000  100.000000     0.000000
# 2415             Queensland  16.600791   75.494071     7.905138
# 2668        South Australia  31.868132   64.835165     3.296703
# 2759         South Carolina   8.800000   82.400000     8.800000
# 2884           South Island  20.689655   75.862069     3.448276
# 2913               Tasmania  28.125000   59.375000    12.500000
# 2945                  Texas   8.064516   83.870968     8.064516
# 3007          Torres Strait   1.666667   95.000000     3.333333
# 3067            Unspecified  34.482759   58.620690     6.896552
# 3068            Unspecified  34.482759   58.620690     6.896552
# 3069            Unspecified  34.482759   58.620690     6.896552
# 3071            Unspecified  34.482759   58.620690     6.896552
# 3074            Unspecified  34.482759   58.620690     6.896552
# 3075            Unspecified  34.482759   58.620690     6.896552
# 3079            Unspecified  34.482759   58.620690     6.896552
# 3082            Unspecified  34.482759   58.620690     6.896552
# 3084            Unspecified  34.482759   58.620690     6.896552
# 3089            Unspecified  34.482759   58.620690     6.896552
# 3096               Victoria  26.229508   65.573770     8.196721
# 3157      Western Australia  23.870968   66.451613     9.677419
# 3312  Western Cape Province  33.908046   62.068966     4.022989
#
#              Country
# 0                USA
# 270     SOUTH AFRICA
# 418              USA
# 1370             USA
# 1618    SOUTH AFRICA
# 1809             USA
# 1844       AUSTRALIA
# 2226             USA
# 2239             USA
# 2327     NEW ZEALAND
# 2366       AUSTRALIA
# 2387             USA
# 2415       AUSTRALIA
# 2668       AUSTRALIA
# 2759             USA
# 2884     NEW ZEALAND
# 2913       AUSTRALIA
# 2945             USA
# 3007       AUSTRALIA
# 3067           JAPAN
# 3068    SOUTH AFRICA
# 3069     NEW ZEALAND
# 3071           MALTA
# 3074           ITALY
# 3075       AUSTRALIA
# 3079  UNITED KINGDOM
# 3082             USA
# 3084       SINGAPORE
# 3089           CHINA
# 3096       AUSTRALIA
# 3157       AUSTRALIA
# 3312    SOUTH AFRICA
#                        Area          N   Unknown          Y         Country
# 0                California  90.000000  0.370370   9.629630             USA
# 270   Eastern Cape Province  82.432432  1.351351  16.216216    SOUTH AFRICA
# 418                 Florida  94.117647  0.945378   4.936975             USA
# 1370                 Hawaii  78.629032  2.016129  19.354839             USA
# 1618          KwaZulu-Natal  69.633508  0.000000  30.366492    SOUTH AFRICA
# 1809             New Jersey  82.857143  2.857143  14.285714             USA
# 1844        New South Wales  77.748691  1.832461  20.418848       AUSTRALIA
# 2226               New York  84.615385  0.000000  15.384615             USA
# 2239         North Carolina  89.772727  0.000000  10.227273             USA
# 2327           North Island  87.179487  5.128205   7.692308     NEW ZEALAND
# 2366     Northern Territory  85.714286  4.761905   9.523810       AUSTRALIA
# 2387                 Oregon  96.428571  0.000000   3.571429             USA
# 2415             Queensland  71.936759  1.581028  26.482213       AUSTRALIA
# 2668        South Australia  74.725275  1.098901  24.175824       AUSTRALIA
# 2759         South Carolina  94.400000  2.400000   3.200000             USA
# 2884           South Island  86.206897  0.000000  13.793103     NEW ZEALAND
# 2913               Tasmania  84.375000  0.000000  15.625000       AUSTRALIA
# 2945                  Texas  88.709677  0.000000  11.290323             USA
# 3007          Torres Strait  71.666667  0.000000  28.333333       AUSTRALIA
# 3067            Unspecified  82.758621  0.000000  17.241379           JAPAN
# 3068            Unspecified  82.758621  0.000000  17.241379    SOUTH AFRICA
# 3069            Unspecified  82.758621  0.000000  17.241379     NEW ZEALAND
# 3071            Unspecified  82.758621  0.000000  17.241379           MALTA
# 3074            Unspecified  82.758621  0.000000  17.241379           ITALY
# 3075            Unspecified  82.758621  0.000000  17.241379       AUSTRALIA
# 3079            Unspecified  82.758621  0.000000  17.241379  UNITED KINGDOM
# 3082            Unspecified  82.758621  0.000000  17.241379             USA
# 3084            Unspecified  82.758621  0.000000  17.241379       SINGAPORE
# 3089            Unspecified  82.758621  0.000000  17.241379           CHINA
# 3096               Victoria  78.688525  3.278689  18.032787       AUSTRALIA
# 3157      Western Australia  75.483871  7.096774  17.419355       AUSTRALIA
# 3312  Western Cape Province  86.206897  0.574713  13.218391    SOUTH AFRICA
#                        Area  Afternoon    Evening    Morning  Unspecified  \
# 0                California  31.111111   6.296296  30.370370    32.222222
# 270   Eastern Cape Province  35.135135   4.729730  24.324324    35.810811
# 418                 Florida  43.592437   7.563025  19.222689    29.621849
# 1370                 Hawaii  30.241935   6.048387  28.629032    35.080645
# 1618          KwaZulu-Natal  38.219895   7.329843  16.230366    38.219895
# 1809             New Jersey  34.285714   2.857143   8.571429    54.285714
# 1844        New South Wales  24.083770  11.256545  18.586387    46.073298
# 2226               New York  30.769231   7.692308   7.692308    53.846154
# 2239         North Carolina  44.318182   9.090909   7.954545    38.636364
# 2327           North Island  38.461538   7.692308   5.128205    48.717949
# 2366     Northern Territory   4.761905   0.000000   0.000000    95.238095
# 2387                 Oregon  39.285714   0.000000  32.142857    28.571429
# 2415             Queensland  23.715415   7.905138  16.996047    51.383399
# 2668        South Australia  29.670330   8.791209  12.087912    49.450549
# 2759         South Carolina  36.000000   8.000000  10.400000    45.600000
# 2884           South Island  20.689655  17.241379  10.344828    51.724138
# 2913               Tasmania  25.000000   6.250000   9.375000    59.375000
# 2945                  Texas  30.645161  20.967742   6.451613    41.935484
# 3007          Torres Strait   5.000000   0.000000   1.666667    93.333333
# 3067            Unspecified   6.896552   0.000000   0.000000    93.103448
# 3068            Unspecified   6.896552   0.000000   0.000000    93.103448
# 3069            Unspecified   6.896552   0.000000   0.000000    93.103448
# 3071            Unspecified   6.896552   0.000000   0.000000    93.103448
# 3074            Unspecified   6.896552   0.000000   0.000000    93.103448
# 3075            Unspecified   6.896552   0.000000   0.000000    93.103448
# 3079            Unspecified   6.896552   0.000000   0.000000    93.103448
# 3082            Unspecified   6.896552   0.000000   0.000000    93.103448
# 3084            Unspecified   6.896552   0.000000   0.000000    93.103448
# 3089            Unspecified   6.896552   0.000000   0.000000    93.103448
# 3096               Victoria  16.393443   4.918033  21.311475    57.377049
# 3157      Western Australia  21.290323   4.516129  21.935484    52.258065
# 3312  Western Cape Province  37.356322   4.022989  17.241379    41.379310
#
#              Country
# 0                USA
# 270     SOUTH AFRICA
# 418              USA
# 1370             USA
# 1618    SOUTH AFRICA
# 1809             USA
# 1844       AUSTRALIA
# 2226             USA
# 2239             USA
# 2327     NEW ZEALAND
# 2366       AUSTRALIA
# 2387             USA
# 2415       AUSTRALIA
# 2668       AUSTRALIA
# 2759             USA
# 2884     NEW ZEALAND
# 2913       AUSTRALIA
# 2945             USA
# 3007       AUSTRALIA
# 3067           JAPAN
# 3068    SOUTH AFRICA
# 3069     NEW ZEALAND
# 3071           MALTA
# 3074           ITALY
# 3075       AUSTRALIA
# 3079  UNITED KINGDOM
# 3082             USA
# 3084       SINGAPORE
# 3089           CHINA
# 3096       AUSTRALIA
# 3157       AUSTRALIA
# 3312    SOUTH AFRICA

# %% [markdown]
# # To be continued...

# %%
df1["No_attacks"] = df1["No_attacks"].astype(int)

# %%
df1=df[["Country", "Area"]]
df1['No_attacks'] = df.groupby(['Country'])['Area'].transform('count')
display(df1)
df2["How_attacks"]=df.groupby(['Area'])["Fatal(Y/N)"].transform()

# %%
locasiones=[]
for e in df["Year"]:
    locasiones.append(e)
cosas=[]
for e in locasiones:
    if len(e)>4:
        cosas.append(e) 
print(cosas)
